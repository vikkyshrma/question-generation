# %% [markdown]
# <a href="https://colab.research.google.com/github/vikkyshrma/question-generation/blob/master/ffreco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
face_cascade = cv2.CascadeClassifier('/content/drive/My Drive/face/drive/gaze/haarcascade_frontalface_default.xml')

# %%
import os
import numpy as np
import PIL
from PIL import Image, ImageOps,ImageEnhance
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
PATH = os.getcwd()
# !pip install keras
from keras.utils import np_utils

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
#from sklearn.model_selection import train_test_split
from keras import backend as K
#K.set_image_dim_ordering('th')

from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD,RMSprop,adam

import cv2

import matplotlib.image as mpimg

from pylab import *
# Out:
# ...
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
PATH = r"/content/drive/My Drive/face/pixxx"

# %%
data_path = PATH

# %%
data_dir_list = os.listdir(data_path)

# %%
data_dir_list
# Out:
# ['mondal', 'shegokar', 'sindu', 'meghwal', 'kanik', 'vikkyshrma']

# %%
LABLE_NAMES = {'mondal':0,'shegokar':1,'sindu':2,'meghwal':3,'kanik':4,'vikkyshrma':5}

# %%
import cv2 
from scipy import misc

# %%
os.getcwd()
# Out:
# '/content'

# %%
class1=[]
label1=[]
for dataset in data_dir_list:
  print(path+'/'+dataset)
  label = LABLE_NAMES[dataset]
  class1.append(path+'/'+dataset)
  label1.append(label)
# Out:
# /content/drive/My Drive/face/pixxx/mondal
# /content/drive/My Drive/face/pixxx/shegokar
# /content/drive/My Drive/face/pixxx/sindu
# /content/drive/My Drive/face/pixxx/meghwal
# /content/drive/My Drive/face/pixxx/kanik
# /content/drive/My Drive/face/pixxx/vikkyshrma

# %%
# Out:
#   File "<ipython-input-64-81e61b2fb9d9>", line 1
#     class1[/content/drive/My Drive/face/pixxx/shegokar]
#            ^
# SyntaxError: invalid syntax

# %%
label1
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
import os
import numpy as np
import matplotlib.pyplot as mpplot
import matplotlib.image as mpimg

images = []
labels_list = []
faces=[]
for root, _, files in os.walk(data_path):
  current_directory_path = os.path.abspath(root)
  for i in label1:
    if(class1[i]==current_directory_path):
      #print(i)
      j=i
    else:
      print('not label folder')


  #print(current_directory_path)
  #print(label)
  for f in files:
        name, ext = os.path.splitext(f)
        if ext == ".jpg":
            current_image_path = os.path.join(current_directory_path, f)
            current_image = mpimg.imread(current_image_path)

            resized = cv2.resize(img, (128,128), interpolation = cv2.INTER_AREA)
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            faces = face_cascade.detectMultiScale(gray, 1.3, 5)
            face.append(faces)
            images.append(resized)
            labels_list.append(j)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-e8d90b00edc7> in <module>()
#      27             resized = cv2.resize(img, (128,128), interpolation = cv2.INTER_AREA)
#      28             gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ---> 29             faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#      30             face.append(faces)
#      31             images.append(resized)
#
# KeyboardInterrupt:

# %%
images = []
labels_list = []
face=[]
i=0
for dataset in data_dir_list:
    img_list=os.listdir(data_path +'/'+ dataset)
  
    print ('Loading the images of dataset-'+'{}\n'.format(dataset))
    label = LABLE_NAMES[dataset]
    print(label)


    for img in img_list:
        current_image_path = data_path+'/'+ dataset+'/'+img
        current_image = mpimg.imread(current_image_path)

        resized = cv2.resize(current_image, (128,128), interpolation = cv2.INTER_AREA)
        gray = cv2.cvtColor(current_image, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
          cv2.rectangle(current_image,(x,y),(x+w,y+h),(0,255,0),2)
          roigray = gray[y:y+h, x:x+w]
          roicolor = current_image[y:y+h, x:x+w]
          facecnt = len(faces)
          print("Detected faces: %d" % facecnt)
          height, width = current_image.shape[:2]
          r = max(w, h) / 2
          centerx = x + w / 2
          centery = y + h / 2
          nx = int(centerx - r)
          ny = int(centery - r)
          nr = int(r * 2)
          faceimg = current_image[ny:ny+nr, nx:nx+nr]
          lastimg = cv2.resize(faceimg, (128, 128))
          i += 1
        face.append(cv2.resize(lastimg, (128,128), interpolation=cv2.INTER_CUBIC))
        images.append(resized)
        labels_list.append(j)
# Out:
# Loading the images of dataset-mondal
#
# 0
# Detected faces: 1
# Detected faces: 2
# Detected faces: 2
# Detected faces: 1
# Detected faces: 2
# Detected faces: 2
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 2
# Detected faces: 2
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Loading the images of dataset-shegokar
#
# 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 2
# Detected faces: 2
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Detected faces: 1
# Loading the images of dataset-sindu
#
# 2
# Detected faces: 1
# Detected faces: 8
# Detected faces: 8
# Detected faces: 8
# Detected faces: 8
# Detected faces: 8
# Detected faces: 8
# Detected faces: 8
# Detected faces: 8
# Detected faces: 2
# ...

# %%
from skimage import io, color

# %%
from skimage.io import imread

# %%
data=[]
for i in images:
  gray = color.rgb2gray(i)
  data.append(gray)

# %%
num_classes = 6
num_channel=1
img_rows=128
img_cols=128

# %%
z = np_utils.to_categorical(labels, num_classes)
##print(z)

# %%
if num_channel==1:
	if K.common.image_dim_ordering()=='th':
		data= np.expand_dims(data, axis=1) 
		print (data.shape)
	else:
		data= np.expand_dims(data, axis=4) 
		print (data.shape)
		
else:
	if K.common.image_dim_ordering()=='th':
		dataa=np.rollaxis(data,3,1)
		print (img_data.shape)
# Out:
# (106, 128, 128, 1)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.

# %%
data[50].shape
# Out:
# (128, 128, 1)

# %%
temp = list(zip(data,z)) 
random.shuffle(temp) 
x,y = zip(*temp)

# %%
X=np.array(x)
Y=np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
X_train.shape
# Out:
# (84, 128, 128, 1)

# %%
y_train.shape
# Out:
# (84, 6)

# %%
batch_size = 64
epochs = 10
num_classes = 6
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D

from keras.layers import LeakyReLU
import keras

# %%
fashion_model = Sequential()
fashion_model.add(Conv2D(32, kernel_size=(3, 3),activation='linear',input_shape=(128,128,1),padding='same'))
fashion_model.add(LeakyReLU(alpha=0.1))
fashion_model.add(MaxPooling2D((2, 2),padding='same'))
fashion_model.add(Conv2D(64, (3, 3), activation='linear',padding='same'))
fashion_model.add(LeakyReLU(alpha=0.1))
fashion_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
fashion_model.add(Conv2D(128, (3, 3), activation='linear',padding='same'))
fashion_model.add(LeakyReLU(alpha=0.1))                  
fashion_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
fashion_model.add(Flatten())
fashion_model.add(Dense(128, activation='linear'))
fashion_model.add(LeakyReLU(alpha=0.1)) 
print(batch_size)                 
fashion_model.add(Dense(num_classes, activation='softmax'))

fashion_model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(),metrics=['accuracy'])
fashion_model.summary()
# Out:
# 64
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_13 (Conv2D)           (None, 128, 128, 32)      320
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 128, 128, 32)      0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 64, 64, 64)        18496
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 32, 32, 128)       73856
# ...

# %%
y_train.shape
# Out:
# (84, 6)

# %%
fashion_train = fashion_model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/10
# ...

# %%
test_eval = fashion_model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 2.097768545150757
# Test accuracy: 0.3181818127632141
